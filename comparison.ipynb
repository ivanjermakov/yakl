# %% [markdown]
# # Efficiency comparison

# %%
from plot import compare_layouts, get_scores

# %%
compare_layouts(lambda tp: tp.distance, "Penalty for the finger travel")

# %%
compare_layouts(lambda tp: tp.finger, "Penalty for the same finger usage")

# %%
compare_layouts(lambda tp: tp.keys, "Penalty for the same hand usage")

# %%
compare_layouts(lambda tp: tp.hand, "Penalty for the non-dominant hand usage")

# %%
compare_layouts(lambda tp: tp.pinky, "Penalty for the pinky usage")

# %%
compare_layouts(lambda tp: tp.sum(), "Penalty total")

# %%
for layout, score in sorted(get_scores(lambda tp: tp.sum()).items(), key=lambda i: i[1]):
    print(f'{layout}{" " * (18 - len(layout))}{round(score, 4)}')
# Out:
# generated         0.1085
# halmak            0.12
# qgmlwy            0.1218
# dvorak            0.1218
# colemak dh mod    0.1237
# colemak           0.1238
# workman           0.1247
# norman            0.1254
# minimak 4-key     0.1564
# row swap (qwdfgy) 0.165
# qwerty            0.1954
