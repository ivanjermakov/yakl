# %% [markdown]
# Alice's Adventures in Wonderland by Lewis Carroll was used as a sample text.

# %%
import matplotlib.pyplot as plt

from text import *

# %%
prepared_text = load_text()
frequency_map = count_letter_frequency(prepared_text)

# %%
plt.bar(*zip(*frequency_map))
plt.title('Character frequency')
plt.show()

# %%
len(prepared_text)
# Out:
# 161443

# %%
bigrams = load_bigram_frequency()

plt.bar(*zip(*list(map(lambda b: (b.first + b.next, b.probability), bigrams))[:20]))
plt.title('Bigram frequency (including characters)')
plt.show()
